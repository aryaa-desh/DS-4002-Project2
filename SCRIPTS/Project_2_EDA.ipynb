# %%
import pandas as pd

df = pd.read_csv('/content/preprocessed_data.csv')
display(df.head())
# Out:
#            State       2001       2002       2003       2004       2005  \
# 0    New England  12.095000  11.244167  11.701667  11.916667  13.445833
# 1    Connecticut  10.923333  10.973333  11.363333  11.640000  13.667500
# 2          Maine  13.180000  12.865000  12.436667  12.191667  13.361667
# 3  Massachusetts  12.490000  10.942500  11.614167  11.756667  13.442500
# 4  New Hampshire  12.460000  11.905833  12.008333  12.535833  13.557500
#
#         2006       2007       2008       2009  ...       2016       2017  \
# 0  15.995833  16.713333  17.689167  17.500833  ...  18.850833  19.435833
# 1  16.931667  19.153333  19.617500  20.380833  ...  20.117500  20.355833
# 2  13.808333  16.561667  16.260833  15.618333  ...  15.840833  15.966667
# 3  16.589167  16.235833  17.595833  16.888333  ...  19.049167  20.095000
# 4  14.722500  14.890000  15.716667  16.405833  ...  18.406667  19.242500
#
#         2018       2019       2020       2021       2022       2023  \
# ...

# %%
# Filter the df to select the row where the "State" column is "United States"
df_us = df[df['State'] == 'United States']
display(df_us)
# Out:
#             State      2001      2002      2003      2004      2005      2006  \
# 61  United States  8.801903  8.673962  8.899481  9.148915  9.706053  10.58717
#
#          2007       2008       2009  ...       2016    2017       2018  \
# 61  11.028506  11.963679  11.955346  ...  13.530597  13.905  14.068664
#
#         2019       2020       2021       2022       2023       2024       2025
# 61  14.22434  14.234308  14.696981  16.218742  17.301651  17.644465  18.270701
#
# [1 rows x 26 columns]

# %%
# reshape the data so that years are in one column and electricity costs in another
df_us_melted = df_us.melt(id_vars='State', var_name='Year', value_name='Electricity Cost')
df_us_melted['Year'] = pd.to_numeric(df_us_melted['Year'])
display(df_us_melted.head())
# Out:
#            State  Year  Electricity Cost
# 0  United States  2001          8.801903
# 1  United States  2002          8.673962
# 2  United States  2003          8.899481
# 3  United States  2004          9.148915
# 4  United States  2005          9.706053

# %%
# Creating the graph
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

df_us_melted_filtered = df_us_melted[df_us_melted['Year'] <= 2021]

plt.figure(figsize=(12, 6))
plt.plot(df_us_melted_filtered['Year'], df_us_melted_filtered['Electricity Cost'])
plt.title("United States Average Electricity Cost Over Time")
plt.xlabel("Year")
plt.ylabel("Average Electricity Cost (cents/kWh)")
plt.grid(True)

# Set x-axis ticks to be whole numbers
plt.gca().xaxis.set_major_locator(mticker.MaxNLocator(integer=True))

plt.show()

# %%
# Extract Virginia data
df_virginia = df[df['State'] == 'Virginia']
display(df_virginia)
# Out:
#        State      2001      2002      2003   2004  2005      2006      2007  \
# 33  Virginia  7.825833  7.796667  7.815833  8.025  8.18  8.496667  8.754167
#
#      2008       2009  ...       2016   2017       2018       2019       2020  \
# 33  9.625  10.650833  ...  11.401667  11.58  11.770833  12.104167  12.071667
#
#        2021   2022    2023       2024       2025
# 33  12.0225  13.38  14.325  14.621667  15.081429
#
# [1 rows x 26 columns]

# %%
# Reshape the data so that years are in one column and electricity costs in another.
df_virginia_melted = df_virginia.melt(id_vars='State', var_name='Year', value_name='Electricity Cost')

# Convert the 'Year' column to numeric
df_virginia_melted['Year'] = pd.to_numeric(df_virginia_melted['Year'])

# Display the head of the melted DataFrame
display(df_virginia_melted.head())
# Out:
#       State  Year  Electricity Cost
# 0  Virginia  2001          7.825833
# 1  Virginia  2002          7.796667
# 2  Virginia  2003          7.815833
# 3  Virginia  2004          8.025000
# 4  Virginia  2005          8.180000

# %%
# Create the graph
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

df_virginia_melted_filtered = df_virginia_melted[df_virginia_melted['Year'] <= 2021]

plt.figure(figsize=(12, 6))
plt.plot(df_virginia_melted_filtered['Year'], df_virginia_melted_filtered['Electricity Cost'])
plt.title("Virginia Average Electricity Cost Over Time (Up to 2021)")
plt.xlabel("Year")
plt.ylabel("Average Electricity Cost (cents/kWh)")
plt.grid(True)

# Set x-axis ticks to be whole numbers
plt.gca().xaxis.set_major_locator(mticker.MaxNLocator(integer=True))

plt.show()
